# %% [markdown]
# # String literals in python are surrounded by either single quotation marks, or double quotation marks.
#
# # 'hello' is the same as "hello".
#
# # You can display a string literal with the print() function:

# %%
"hello"
# Out:
# 'hello'

# %%
'hello'
# Out:
# 'hello'

# %%
type("hello")
# Out:
# str

# %% [markdown]
# # Multiline Strings
# * You can assign a multiline string to a variable by using three quotes:

# %%
string = """Hey, you !
    Haan, you.
    Whrere are you looking at ?
    Do Python Everyday.
    You cant just see and learm python.
    You need to practice it everyday...
    Solve basic problems as you did in C, C++
    the nmove towards larger problems
"""
print(string)
# Out:
# Hey, you !
#     Haan, you.
#     Whrere are you looking at ?
#     Do Python Everyday.
#     You cant just see and learm python.
#     You need to practice it everyday...
#     Solve basic problems as you did in C, C++
#     the nmove towards larger problems

# %% [markdown]
# # INDICES

# %%
string = "Hello World"
print(string[0])
print(string[1])
print(string[2])
print(string[3])
print(string[4])
print(string[5])
print(string[6])
print(string[7])
print(string[8])
print(string[9])
print(string[10])
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# # Reverse indices starts from -1

# %%
string = "Hello World"
print(string[-1])
print(string[-2])
print(string[-3])
print(string[-4])
print(string[-5])
print(string[-6])
print(string[-7])
print(string[-8])
print(string[-9])
print(string[-10])
# Out:
# d
# l
# r
# o
# W
#
# o
# l
# l
# e

# %% [markdown]
# # substring

# %%
string
# Out:
# 'Hello World'

# %%
string[2:5]
# Out:
# 'llo'

# %%
string[:]
# Out:
# 'Hello World'

# %%
string[4:]
# Out:
# 'o World'

# %%
string{:4}
# Out:
#   File "<ipython-input-15-707bec5c1b86>", line 1
#     string{:4}
#           ^
# SyntaxError: invalid syntax

# %%
string
# Out:
# 'Hello World'

# %%
string[0:4}
# Out:
#   File "<ipython-input-18-30edc1df2fee>", line 1
#     string[0:4}
#               ^
# SyntaxError: invalid syntax
