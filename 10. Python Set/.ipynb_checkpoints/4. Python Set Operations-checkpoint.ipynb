# %% [markdown]
# # union

# %%
from IPython.display import Image
Image("img/p2c6-union.png")

# %%
s1 = {5, 10, 15, 20, 25}
s2 = {20, 25, 30, 35}
s1 | s2
# s1.union(s2)
# Out:
# {5, 10, 15, 20, 25, 30, 35}

# %% [markdown]
# # difference

# %%
s1 = {5, 10, 15, 20, 25}
s2 = {20, 25, 30, 35}
s1 & s2
# Out:
# {20, 25}

# %%
from IPython.display import Image
Image("img/p2c6-intersection.png")

# %% [markdown]
# # difference

# %%
s1 = {5, 10, 15, 20, 25}
s2 = {20, 25, 30, 35}
s1 - s2
# Out:
# {5, 10, 15}

# %%
from IPython.display import Image
Image("img/p2c6-difference.png")

# %%
# set symmetric difference

# %%
s1 = {5, 10, 15, 20, 25}
s2 = {20, 25, 30, 35}
s1 ^ s2
# Out:
# {5, 10, 15, 30, 35}

# %%
from IPython.display import Image
Image("img/p2c6-symmdiff.png")
