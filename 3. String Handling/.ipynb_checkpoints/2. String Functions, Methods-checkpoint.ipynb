# %% [markdown]
# # String functions

# %% [markdown]
# # str.count()

# %%
# The count() method returns the number of times a specified value appears in the string.

# %%
# return the number of times the value "apple" appears in the string:

# %%
"i love apple, apple is good food, i like apple juice.".count("apple")
# Out:
# 3

# %% [markdown]
# # capitalize() : Converts first character to Capital Letter

# %%
"i love apple, apple is good food, i like apple juice.".capitalize()
# Out:
# 'I love apple, apple is good food, i like apple juice.'

# %%
"i love apple. apple is good food. i like apple juice.".capitalize()
# Out:
# 'I love apple. apple is good food. i like apple juice.'

# %%
# center()

# %%
# center() Method With Default fillchar

# %%
"Python is great".center(30)
# Out:
# '       Python is great        '

# %%
# center() Method With * fillchar

# %%
"Python is great".center(30, '*')
# Out:
# '*******Python is great********'

# %%
# endswith

# %%
# The endswith() method returns True if a string ends with the specified suffix. If not, it returns False

# %%
# 1. endswith() Without start and end Parameters

# %%
text = "Python is easy to learn."

result = text.endswith('to learn')
# returns False
print(result)

result = text.endswith('to learn.')
# returns True
print(result)

result = text.endswith('Python is easy to learn.')
# returns True
print(result)
# Out:
# False
# True
# True

# %%
# 1. endswith() With start and end Parameters

# %%
text = "Python programming is easy to learn."

# start parameter: 7
# "programming is easy to learn." string is searched
result = text.endswith('learn.', 7)
print(result)

# Both start and end is provided
# start: 7, end: 26
# "programming is easy" string is searched

result = text.endswith('is', 7, 26)
# Returns False
print(result)

result = text.endswith('easy', 7, 26)
# returns True
print(result)
# Out:
# True
# False
# True

# %%
# isalnum() characters + numbers + no spaces + no comma + no dot+ no special characters

# %%
"150".isalnum()
# Out:
# True

# %%
"Python".isalnum()
# Out:
# True

# %%
"Python36".isalnum()
# Out:
# True

# %%
"python%&36".isalnum()
# Out:
# False

# %%
# some practical example with string.isalnum()

# %%
if("I like apple. Apple is the best fruit for health. Apple Juice is delicious".isalnum()==True):
    print("string is alpha-numerical")
else:
    print("string contains some special characters")
# Out:
# string contains some special characters

# %%
if("I like apple Apple is the best fruit for health Apple Juice is delicious".isalnum()==True):
    print("string is alpha-numerical")
else:
    print("string contains some special characters")
# Out:
# string contains some special characters

# %%
if("I like apple5 Apple is the best fruit for health5 Apple Juice is delicious".isalnum()==True):
    print("string is alpha-numerical")
else:
    print("string contains some special characters")
# Out:
# string contains some special characters

# %%
"".join("I like apple5 Apple is the best fruit for health5 Apple Juice is delicious".split())
# Out:
# 'Ilikeapple5Appleisthebestfruitforhealth5AppleJuiceisdelicious'

# %%
"Ilikeapple5Appleisthebestfruitforhealth5AppleJuiceisdelicious".isalnum()
# Out:
# True

# %%
if("IlikeappleAppleisthebestfruitforhealthAppleJuiceisdelicious".isalnum() == True):
     print("string is alpha-numerical")
else:
    print("string contains some special characters")
# Out:
# string is alpha-numerical

# %%
# string isalpha()

# %%
"Penan".isalpha()
# Out:
# True

# %%
"Penan ".isalpha()
# Out:
# False

# %%
"454854".isalpha()
# Out:
# False

# %%
"jdfj565".isalpha()
# Out:
# False

# %%
# isnumeric()

# %%
"447".isnumeric()
# Out:
# True

# %%
"56485 ".isnumeric()
# Out:
# False

# %%
"65649a".isnumeric()
# Out:
# False

# %%
# isdigit()

# %%
"6264650".isdigit()
# Out:
# True

# %%
# isspace()

# %%
spaced = "hdash hdjuasud 565"
spaced.isspace()
# Out:
# False

# %%
" ".isspace()
# Out:
# True

# %%
"  \t".isspace()
# Out:
# True

# %%
"  ".isspace()
# Out:
# True

# %%
if(input().isspace() == True ):
    print("You should not enter white spaces")
else:
    print("you entered text")
# Out:
# PENAN PRAKASH RAJPUT
# you entered text

# %%
if(input().isspace() == True ):
    print("You should not enter white spaces")
else:
    print("you entered text")
# Out:
#
# You should not enter white spaces

# %%
# title()

# %%
"apple is most trusted brand in the world".title()
# Out:
# 'Apple Is Most Trusted Brand In The World'

# %%
# istitle() 
# checks for titlecase
# apple is best pc => titlecase => Apple Is My Best Pc

# %%
"apple is most trusted brand".istitle()
# Out:
# False

# %%
"Apple is most trusted brand".istitle()
# Out:
# False

# %%
"Apple is most trusted brand".istitle()
# Out:
# False

# %%
s = 'Python Is Good.'
print(s.istitle())

s = 'Python is good'
print(s.istitle())

s = 'This Is @ Symbol.'
print(s.istitle())

s = '99 Is A Number'
print(s.istitle())

s = 'PYTHON'
print(s.istitle())
# Out:
# True
# False
# True
# True
# False

# %%
# bool()   isbool()
# title()  istitle()
# lower()  islower()
# upper()  isupper()

# %%
# strip()
# lstrip()
# rstrip()

# %%
# join()

# %%
bool("True")
# Out:
# True

# %%
bool("nasdjas")
# Out:
# True

# %%
bool("15156")
# Out:
# True

# %%
test = []
print(test,'is',bool(test))

test = [0]
print(test,'is',bool(test))

test = 0.0
print(test,'is',bool(test))

test = None
print(test,'is',bool(test))

test = True
print(test,'is',bool(test))

test = 'Easy string'
print(test,'is',bool(test))
# Out:
# [] is False
# [0] is True
# 0.0 is False
# None is False
# True is True
# Easy string is True

# %%
# string.join(iterable)
"/".(" asnfjansdja bndajs d asdmakdnak ndaspi")
# Out:
#   File "<ipython-input-17-5a02290d387a>", line 2
#     "/".(" asnfjansdja bndajs d asdmakdnak ndaspi")
#         ^
# SyntaxError: invalid syntax

# %%
# itearable is list here
var = ["Penan", "Rajput", "Programmer"]
"/".join(var)
# Out:
# 'Penan/Rajput/Programmer'

# %%
", ".join(var)
# Out:
# 'Penan, Rajput, Programmer'

# %%
type(", ".join(var))
# Out:
# str

# %%
type(var)
# Out:
# list

# %%
float("4213.12312")
# Out:
# 4213.12312

# %%
# converts to 
# Its like TYPECAST
# int() 
# float()
# complex()
# bool()

# %%
int("53sda")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-737aa4191a8a> in <module>
# ----> 1 int("dsf")
#
# ValueError: invalid literal for int() with base 10: 'dsf'
